# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# # Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details:
# # A) Rank B) Name C) Artist D) Upload date E) Views

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time


# webdriver creation and opening the url 
driver = webdriver.Chrome(r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe")
url= "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver.get(url)
time.sleep(2)

search=driver.find_element_by_id("searchInput")
search.send_keys("list of most viewed YouTube videos")
driver.find_element_by_id("searchButton").click()

# %%
table_tag=driver.find_element_by_xpath("//*[@id='mw-content-text']/div[1]/table[1]/tbody")

rank=[]
name=[]
artist=[]
views=[]
upload=[]

rank_tag=table_tag.find_elements_by_xpath("./tr/td[1]")
for row in rank_tag:
    rank.append(row.text)

names=[]
name_tag=table_tag.find_elements_by_xpath("./tr/td[2]")
for row in name_tag:
    names.append(row.text)
for i in names:
    name.append(i[1:-5])

artist_tag=table_tag.find_elements_by_xpath("./tr/td[3]")
for row in artist_tag:
    artist.append(row.text)

views_tag=table_tag.find_elements_by_xpath("./tr/td[4]")
for row in views_tag:
    views.append(row.text)

upload_tag=table_tag.find_elements_by_xpath("./tr/td[5]")
for row in upload_tag:
    upload.append(row.text)

# %%
len(name)
# Out:
# 30

# %%
import pandas as pd

Most_Youtube_Videos=pd.DataFrame({})

Most_Youtube_Videos["Rank"]=rank
Most_Youtube_Videos["Name"]=name
Most_Youtube_Videos["artist"]=artist
Most_Youtube_Videos["Views"]=views
Most_Youtube_Videos["upload"]=upload
Most_Youtube_Videos
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                               Shape of You
# 3    4.                              See You Again
# 4    5.                       Johny Johny Yes Papa
# 5    6.   Masha and the Bear – Recipe for Disaster
# 6    7.                                Uptown Funk
# 7    8.                              Gangnam Style
# 8    9.  Learning Colors – Colorful Eggs on a Farm
# 9   10.                                  Bath Song
# 10  11.                Phonics Song with Two Words
# 11  12.                                      Sorry
# 12  13.                                      Sugar
# 13  14.                                       Roar
# 14  15.                             Counting Stars
# 15  16.                          Thinking Out Loud
# 16  17.                             Dame Tu Cosita
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# # You need to find following details:
# # A) Match title (I.e. 1st ODI)
# # B) Series
# # C) Place
# # D) Date
# # E) Time
# # Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time


# webdriver creation and opening the url 
driver = webdriver.Chrome(r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe")
url= "https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import wait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains

international_tag=driver.find_element_by_xpath("//li[@class='navigation__item'][@data-nav-index='0']")
fixtures_tag=international_tag.find_element_by_xpath("./div[2]/div/ul/li[1]/a")

actions = ActionChains(driver)
actions.move_to_element(international_tag).move_to_element(fixtures_tag).click().perform()

# %%
matches_tag=driver.find_elements_by_xpath("//div[@class='js-list']/a")

# %%
matches_tag[2].text
# Out:
# 'Thursday\n04\nMARCH\n09:30 IST\nTEST\nINDIA V ENGLAND 2021\n4th Test\nSardar Patel Stadium, Ahmedabad\nINDIA\nv\nENGLAND\nMATCH CENTRE'

# %%
match_day=[]
for row in matches_tag:
    match_day.append(row.find_element_by_xpath("./div").text)

# %%
weekday=[]
day=[]
month=[]
time=[]
for date in match_day:
    weekday.append(date.split("\n")[0])
    day.append(date.split("\n")[1])
    month.append(date.split("\n")[2])
    time.append(date.split("\n")[3])

# %%
format_tag=driver.find_elements_by_xpath("/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]")

# %%
match_format=[]
series=[]
match_details=[]
stadium=[]
details=[]
for row in format_tag:
    details.append(row.text)
for row in details:
    match_format.append(row.split("\n")[0])
    series.append(row.split("\n")[1])
    match_details.append(row.split("\n")[2])
    stadium.append(row.split("\n")[3])
    
vs_teams=[]
teams_tag=driver.find_elements_by_xpath("//html/body/div[4]/div/div/div[2]/section/div/div/a/div[3]")
for row in teams_tag:
    vs_teams.append(row.text)

teams=[]
for i in range(0,len(vs_teams)):
    teams.append(vs_teams[i].replace("\n"," "))

# %%
date_time = [i +" "+ j+" "+ k for i, j, k in zip(weekday,day, month)]

# %%
import pandas as pd
BCCI=pd.DataFrame({})
BCCI["Match Title"]=match_details
BCCI["Series"]=series

BCCI["Weekday"]=weekday
#BCCI["Date"]=day
BCCI["Date Time"]=date_time
BCCI["Time"]=time
BCCI["Stadium"]=stadium
BCCI
# Out:
#    Match Title                Series    Weekday              Date Time  \
# 0     2nd Test  INDIA V ENGLAND 2021   Saturday   Saturday 13 FEBRUARY
# 1     3rd Test  INDIA V ENGLAND 2021  Wednesday  Wednesday 24 FEBRUARY
# 2     4th Test  INDIA V ENGLAND 2021   Thursday      Thursday 04 MARCH
# 3     1st T20I  INDIA V ENGLAND 2021     Friday        Friday 12 MARCH
# 4     2nd T20I  INDIA V ENGLAND 2021     Sunday        Sunday 14 MARCH
# 5     3rd T20I  INDIA V ENGLAND 2021    Tuesday       Tuesday 16 MARCH
# 6     4th T20I  INDIA V ENGLAND 2021   Thursday      Thursday 18 MARCH
# 7     5th T20I  INDIA V ENGLAND 2021   Saturday      Saturday 20 MARCH
# 8      1st ODI  INDIA V ENGLAND 2021    Tuesday       Tuesday 23 MARCH
# 9      2nd ODI  INDIA V ENGLAND 2021     Friday        Friday 26 MARCH
# 10     3rd ODI  INDIA V ENGLAND 2021     Sunday        Sunday 28 MARCH
# 11    1st Test  ENGLAND V INDIA 2021  Wednesday    Wednesday 04 AUGUST
# ...

# %% [markdown]
# # Q3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time


# webdriver creation and opening the url 
driver = webdriver.Chrome(r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe")
url= "https://www.guru99.com/"
driver.get(url)
time.sleep(2)

# %%
from selenium.webdriver.support.ui import Select

# %%
from selenium.webdriver import ActionChains
testing_tag=driver.find_element_by_xpath("//ul[@class='g-toplevel']/li[2]")
selenium_tag=testing_tag.find_element_by_xpath('//*[@id="menu-3688-particle"]/nav/ul/li[2]/ul/li/div/div[3]/ul/li[5]/a/span/span')

actions=ActionChains(driver)
actions.move_to_element(testing_tag).move_to_element(selenium_tag).click().perform()

# %%
# driver.find_element_by_class_name("CloseButton__ButtonElement-sc-79mh24-0 gVNUOF aurora-CloseButton aurora-close aurora-ClosePosition--top-right")

escape_tag=driver.find_element_by_id("om-dgojyzueujjf7huvd8jh-yesno")
escape_tag.find_element_by_xpath("//button[@title='Close']").click()

# %%
#tutorial_tag=driver.find_element_by_xpath("//*[contains(text(),'Exception Handling')]")
tutorial_tag=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']").click()
time.sleep(2)

# %%
table_tag=driver.find_element_by_xpath("//*[@id='g-mainbar']/div[1]/div/div/div/div/div/div[2]/table/tbody")

# %%
exceptions=[]
description=[]

exception_name_tag=table_tag.find_elements_by_xpath("./tr/td[1]")
for row in exception_name_tag[1:]:
    exceptions.append(row.text)

description_tag=table_tag.find_elements_by_xpath("./tr/td[2]")
for row in description_tag[1:]:
    description.append(row.text)

# %%
import pandas as pd
Selenium_exceptions=pd.DataFrame({})

Selenium_exceptions["Exception name"]=exceptions
Selenium_exceptions["Description"]=description
Selenium_exceptions
# Out:
#                          Exception name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# # Q4 - Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# # You have to find following details:
# # A) Rank
# # B) State
# # C) GSDP(18-19)
# # D) GSDP(17-18)
# # E) Share(2017)
# # F) GDP($ billion)
# # Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time


# webdriver creation and opening the url 
driver = webdriver.Chrome(r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe")
url= "http://statisticstimes.com/"
driver.get(url)
time.sleep(2)

# %%
from selenium.webdriver import ActionChains
economy_tag=driver.find_element_by_xpath("//div[@class='navbar']/div[2]")
country_tag=economy_tag.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')

actions=ActionChains(driver)
actions.move_to_element(economy_tag).move_to_element(country_tag).click().perform()

# %%
indian_states_tag=driver.find_element_by_xpath("//*[contains(text(),'GDP of Indian states')]").click()
#/html/body/div[2]/div[2]/div[2]/ul/li[1]/a

# %%
states_table=driver.find_element_by_id("table_id").find_element_by_xpath("./tbody")

# %%
rank=[]
states=[]
gdsp_19=[]
gsdp_18=[]
share=[]
gdp=[]

rank_tag=states_table.find_elements_by_xpath("./tr/td[1]")
for row in rank_tag:
    rank.append(row.text)

states_tag=states_table.find_elements_by_xpath("./tr/td[2]")
for row in states_tag:
    states.append(row.text)
    
gdsp_19_tag=states_table.find_elements_by_xpath("./tr/td[3]")
for row in gdsp_19_tag:
    gdsp_19.append(row.text)
    
gdsp_18_tag=states_table.find_elements_by_xpath("./tr/td[4]")
for row in gdsp_18_tag:
    gsdp_18.append(row.text)
    
share_tag=states_table.find_elements_by_xpath("./tr/td[5]")
for row in share_tag:
    share.append(row.text)

gdp_tag=states_table.find_elements_by_xpath("./tr/td[6]")
for row in gdp_tag:
    gdp.append(row.text)

# %%
import pandas as pd
GSDP=pd.DataFrame({})

GSDP["Rank"]=rank
GSDP["State"]=states
GSDP["GSDP for Year 19/20"]=gdsp_19
GSDP["GSDP for Year 18/19"]=gsdp_18
GSDP["Share"]=share
GSDP["GDP"]=gdp

GSDP
# Out:
#    Rank                      State GSDP for Year 19/20 GSDP for Year 18/19  \
# 0     1                Maharashtra                   -           2,632,792
# 1     2              Uttar Pradesh           1,794,508           1,668,229
# 2     3                 Tamil Nadu           1,845,853           1,630,208
# 3     4                  Karnataka           1,699,115           1,544,399
# 4     5                    Gujarat                   -           1,502,899
# 5     6                West Bengal           1,253,832           1,089,898
# 6     7                  Rajasthan           1,020,989             942,586
# 7     8             Andhra Pradesh             972,782             862,957
# 8     9                  Telangana             969,604             861,031
# 9    10             Madhya Pradesh             906,672             809,592
# 10   11                     Kerala                   -             781,653
# ...

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# # You have to find the following details:
# # A) Repository title
# # B) Repository description
# # C) Contributors count
# # D) Language used

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver import ActionChains

# webdriver creation and opening the url 
path=r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe"
driver = webdriver.Chrome(path)
url= "https://github.com"
driver.get(url)
time.sleep(2)

# %%
explore_tag=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
trending_tag=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]")

actions=ActionChains(driver)

explore_click=actions.move_to_element(explore_tag).click().perform
time.sleep(3)
trending_click=actions.move_to_element(trending_tag).click().perform()

# %%
title_tag=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
title=[]
for row in title_tag:
    title.append(row.text)


description=[]
language=[]
boxrow=driver.find_elements_by_class_name("Box-row")
for item in boxrow:
    try:
        description_tag=item.find_element_by_xpath("./p[@class='col-9 text-gray my-1 pr-4']")
        description.append(description_tag.text)
    except NoSuchElementException as e:
        description.append("No description available for this repository")
        
    try:
        language_tag=item.find_element_by_xpath("./span[@class='d-inline-block ml-0 mr-3']")
        language.append(language_tag.text)
    except NoSuchElementException as e:
        language.append("No Language")

contribution=[]
contribution_tag=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/a[2]")
for row in contribution_tag:
    contribution.append(row.text)

# %%
github=pd.DataFrame({})
github["Repository Title"]=title
github["Repository Description"]=description
github["Language"]=language
github["Contribution"]=contribution
github
# Out:
#                       Repository Title  \
# 0                   conwnet / github1s
# 1   Azure / azure-quickstart-templates
# 2      iam-abbas / Reddit-Stock-Trends
# 3         Azure / azure-rest-api-specs
# 4                      iptv-org / iptv
# 5               JonnyBurger / remotion
# 6                    hashicorp / vault
# 7      aws / amazon-sagemaker-examples
# 8          felixge / go-profiler-notes
# 9       JonnyBurger / remotion-trailer
# 10        mozilla-mobile / firefox-ios
# 11            Azure / azure-powershell
# 12                   sveltejs / svelte
# 13             excalidraw / excalidraw
# 14     engindemirog / KampFinalProject
# 15               streamich / react-use
# 16  hashicorp / terraform-provider-aws
# 17      jomjol / AI-on-the-edge-device
# 18    goldbergyoni / nodebestpractices
# 19                     Seagate / cortx
# 20           reed-hong / awesome-libra
# 21                inancgumus / learngo
# 22  swisskyrepo / PayloadsAllTheThings
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com. Url = https://www.billiboard.com/
# # You have to find the following details:
# # A) Song name
# # B) Artist name
# # C) Last week rank
# # D) Peak rank
# # E) Weeks on board
# # Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time


# webdriver creation and opening the url 
path=r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe"
driver = webdriver.Chrome(path)
url= "https://www.billboard.com/"
driver.get(url)
time.sleep(2)

# %%
#top100=driver.find_element_by_xpath("//*[contains(text(),'Hot 100')]/preceding-sibling::li")

top100=driver.find_element_by_link_text("HOT 100").click()

# %%
list_tag=driver.find_element_by_xpath("//ol[@class='chart-list__elements']")

# %%
position_tag=list_tag.find_elements_by_xpath("//span[@class='chart-element__rank__number']")
song_tag=list_tag.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
artist_tag=list_tag.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
lastwk_tag=list_tag.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
peakwk_tag=list_tag.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
durationwk_tag=list_tag.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")

# %%
position=[]
for row in position_tag:
    position.append(row.text)

song_name=[]
for row in song_tag:
    song_name.append(row.text)

artist_name=[]
for row in artist_tag[0:100]:
    artist_name.append(row.text)
    
lastwk=[]
for row in lastwk_tag:
    lastwk.append(row.text)

peakwk=[]
for row in peakwk_tag:
    peakwk.append(row.text)
    
durationwk=[]
for row in durationwk_tag:
    durationwk.append(row.text)

# %%
len(artist_name),len(song_name),len(position),len(lastwk),len(peakwk),len(durationwk)
# Out:
# (100, 100, 100, 100, 100, 100)

# %%
import pandas as pd
BillBoard=pd.DataFrame({})
BillBoard["This Week"]=position
BillBoard["Song Name"]=song_name
BillBoard["Artist Name"]=artist_name
BillBoard["Last Week"]=lastwk
BillBoard["Peak Week"]=peakwk
BillBoard["Weeks on Charts"]=durationwk
BillBoard
# Out:
#    This Week        Song Name                               Artist Name  \
# 0          1  Drivers License                            Olivia Rodrigo
# 1          2             Mood              24kGoldn Featuring iann dior
# 2          3  Blinding Lights                                The Weeknd
# 3          4            34+35                             Ariana Grande
# 4          5       Levitating                 Dua Lipa Featuring DaBaby
# ..       ...              ...                                       ...
# 95        96        Fake Woke                             Tom MacDonald
# 96        97         Prisoner            Miley Cyrus Featuring Dua Lipa
# 97        98        Dangerous                             Morgan Wallen
# 98        99    Almost Maybes                              Jordan Davis
# 99       100    Mr. Right Now  21 Savage & Metro Boomin Featuring Drake
#
#    Last Week Peak Week Weeks on Charts
# 0          1         1               4
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# # Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# # You have to find the following details:
# # A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd


# webdriver creation and opening the url 
driver = webdriver.Chrome(r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe")
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(2)

# %%
table_tag=driver.find_element_by_xpath("//table[@class='in-article sortable']/tbody")

# %%
rank=[]
rank_tag=table_tag.find_elements_by_xpath("./tr/td[1]")
for row in rank_tag:
    rank.append(row.text)

title=[]
title_tag=table_tag.find_elements_by_xpath("./tr/td[2]")
for row in title_tag:
    title.append(row.text)
    
author=[]
author_tag=table_tag.find_elements_by_xpath("./tr/td[3]")
for row in author_tag:
    author.append(row.text)

publisher=[]
publisher_tag=table_tag.find_elements_by_xpath("./tr/td[4]")
for row in publisher_tag:
    publisher.append(row.text)

genre=[]
genre_tag=table_tag.find_elements_by_xpath("./tr/td[5]")
for row in genre_tag:
    genre.append(row.text)

# %%
Books=pd.DataFrame({})
Books["Rank"]=rank
Books["Title"]=title
Books["Author"]=author
Books["Publisher"]=publisher
Books["Genre"]=genre
Books
# Out:
#    Rank                                              Title            Author  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#     Publisher            Genre
# ...

# %% [markdown]
# # Q9: 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# # You have to find the following details:
# # A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd


# webdriver creation and opening the url 
path=r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe"
driver = webdriver.Chrome(path)
url= " https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(2)

# %%
list_tag=driver.find_element_by_class_name("lister-list")

# %%
position=list_tag.find_elements_by_class_name("lister-item-header")
rank=[]
show=[]
span=[]
for row in position:
    rank.append(row.text.split(" ")[0])
    show.append(row.text.split(".")[1].split("(")[0])
    span.append(row.text.split("(")[1].replace(")",""))

# %%
runtime=[]
runtime_tag=list_tag.find_elements_by_xpath("//span[@class='runtime']")
for row in runtime_tag:
    runtime.append(row.text)

genre=[]
genre_tag=list_tag.find_elements_by_xpath("//span[@class='genre']")
for row in genre_tag:
    genre.append(row.text)

ratings=[]
ratings_tag=list_tag.find_elements_by_xpath("//div[@class='ipl-rating-widget']")
for row in ratings_tag:
    ratings.append(row.text.split("\n")[0])
    
votes=[]
votes_tag=list_tag.find_elements_by_xpath("//*[@id='main']/div/div[3]/div[3]/div/div[2]/p[4]/span[2]")

for row in votes_tag:
    votes.append(row.text)

# %%
imdb=pd.DataFrame({})
imdb["Rank"]=rank
imdb["Name of the show"]=show
imdb["Year Span"]=span
imdb["Run time"]=runtime
imdb["Ratings"]=ratings
imdb["Votes"]=votes
imdb
# Out:
#     Rank                  Name of the show  Year Span Run time Ratings  \
# 0     1.                  Game of Thrones   2011–2019   57 min     9.3
# 1     2.                  Stranger Things      2016–    51 min     8.7
# 2     3.                 The Walking Dead      2010–    44 min     8.2
# 3     4.                   13 Reasons Why   2017–2020   60 min     7.6
# 4     5.                          The 100   2014–2020   43 min     7.6
# ..   ...                               ...        ...      ...     ...
# 95   96.                            Reign   2013–2017   42 min     7.5
# 96   97.   A Series of Unfortunate Events   2017–2019   50 min     7.8
# 97   98.                   Criminal Minds   2005–2020   42 min     8.1
# 98   99.            Scream: The TV Series   2015–2019   45 min     7.2
# 99  100.       The Haunting of Hill House        2018  572 min     8.6
#
#         Votes
# 0   1,768,209
# 1     820,820
# 2     852,702
# 3     255,982
# 4     216,183
# ..        ...
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# # You have to find the following details:
# # A) Dataset name B) Data type C) Task D) Attribute type  E) No of instances F) No of attribute G) Year

# %%
import selenium 
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd


# webdriver creation and opening the url 
path=r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe"
driver = webdriver.Chrome(path)
url= "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

# %%
driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]").click()

# %%
table_tag=driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]")

# %%
name=[]
name_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[1]")
for row in name_tag:
    name.append(row.text)

data_type=[]
data_type_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[2]")
for row in data_type_tag:
    data_type.append(row.text)

task=[]
task_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[3]")
for row in task_tag:
    task.append(row.text)

attribute=[]
attribute_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[4]")
for row in attribute_tag:
    attribute.append(row.text)

instances=[]
instances_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[5]")
for row in instances_tag:
    instances.append(row.text)

no_of_attributes=[]
no_of_attributes_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[6]")
for row in no_of_attributes_tag:
    no_of_attributes.append(row.text)

year=[]
year_tag=table_tag.find_elements_by_xpath("./tbody/tr/td[7]")
for row in year_tag:
    year.append(row.text)

# %%
uci=pd.DataFrame({})
uci["Name"]=name
uci["Data Type"]=data_type
uci["Default Task"]=task
uci["Attribute Type"]=attribute
uci["Instances"]=instances
uci["# of Attributes"]=no_of_attributes
uci["Year"]=year
uci[1:]
# Out:
#                                                   Name      Data Type  \
# 1                                              Abalone  Multivariate
# 2                                                Adult  Multivariate
# 3                                            Annealing  Multivariate
# 4                         Anonymous Microsoft Web Data
# 5                                           Arrhythmia  Multivariate
# ..                                                 ...            ...
# 555          IIWA14-R820-Gazebo-Dataset-10Trajectories
# 556                     Guitar Chords finger positions          Text
# 557               Russian Corpus of Biographical Texts          Text
# 558                                        Codon usage  Multivariate
# 559    Intelligent Media Accelerometer and Gyroscop...   Time-Series
#
#                     Default Task               Attribute Type Instances  \
# 1                Classification   Categorical, Integer, Real      4177
# ...

# %% [markdown]
# # Q7: Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# # You have to find the following details:
# # A) Name B) Designation C) Company D) Skills they hire for E) Location
# # Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time

path=r"C:\Users\Home\Downloads\Nayeem\FlipRobo internship\WebSCraper\chromedriver.exe"
driver=webdriver.Chrome(path)
url="https://www.naukri.com"

driver.get(url)
time.sleep(2)

# %%
from selenium.webdriver import ActionChains

recruiter=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
browse_recruiter=recruiter.find_element_by_xpath("//a[@title='Browse All Recruiters']")

actions=ActionChains(driver)

# %%
actions.move_to_element(recruiter).move_to_element(browse_recruiter).click().perform()

# %%
allwindows=driver.window_handles

# %%
driver.switch_to.window(allwindows[1])

# %%
search=driver.find_element_by_xpath("//*[@id='skill']/div[1]/div[2]/input")
search.send_keys("Data Science")
driver.find_element_by_id("qsbFormBtn").click()

# %%
details_tag=driver.find_element_by_xpath("//div[@class='outerRecSec']")

# %%
name=[]
name_tag=details_tag.find_elements_by_xpath("//span[@class='fl ellipsis']")
for row in name_tag:
    name.append(row.text)

designation=[]
designation_tag=details_tag.find_elements_by_xpath("//span[@class='ellipsis clr']")
for row in designation_tag:
    designation.append(row.text)

company=[]
company_tag=details_tag.find_elements_by_xpath("//a[@class='ellipsis'][2]")
for row in company_tag:
    company.append(row.text)

skill=[]
skill_tag=details_tag.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for row in skill_tag:
    skill.append(row.text)

location=[]
locations=[]
#location_tag=details_tag.find_elements_by_xpath("//small[@class='ellipsis']")
location_tag=details_tag.find_elements_by_xpath("//p[@class='highlightable']")
for row in location_tag:
    location.append(row.text.split("\n"))
for i in range(0,len(location_tag)):
    if len(location[i])<4:
        location[i].append("NO CITY LISTED")
for i in range(0,len(location)):
    locations.append(location[i][3])
# Out:
# the value of i is: 27
# the value of i is: 44

# %%
Naukri=pd.DataFrame({})
Naukri["Recruiter Name"]=name
Naukri["Designation"]=designation
Naukri["Company Name"]=company
Naukri["Skills Hire"]=skill
Naukri["location"]=locations
Naukri
# Out:
#                                    Recruiter Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6                                  Jitendra Singh
# 7    Abhishek - Only Analytics Hiring - India and
# 8   Institute for Financial Management and Resear
# 9                                     Balu Ramesh
# 10                                  Asif Lucknowi
# 11                                InstaFinancials
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                  Manisha Yadav
# 16                                   Kapil Devang
# 17                                    Riya Rajesh
# ...
